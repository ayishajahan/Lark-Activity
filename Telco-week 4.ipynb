# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Question 1

# %%
zen=pd.read_csv('telco.csv')

# %%
zen.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
sns.countplot(x='Churn', hue='gender', data=zen)
# Out:
# <AxesSubplot:xlabel='Churn', ylabel='count'>

# %% [markdown]
# # Question 2

# %%
SCF=zen.loc[(zen["gender"]=="Female") & (zen["SeniorCitizen"]==1)]
SCF
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 30    3841-NFECX  Female              1     Yes         No      71
# 50    8012-SOUDQ  Female              1      No         No      43
# 52    6575-SUVOI  Female              1     Yes         No      25
# 53    7495-OOKFY  Female              1     Yes         No       8
# 54    4667-QONEA  Female              1     Yes        Yes      60
# ...          ...     ...            ...     ...        ...     ...
# 6993  6583-QGCSI  Female              1     Yes         No      50
# 7008  1980-KXVPM  Female              1      No         No       3
# 7010  0723-DRCLG  Female              1     Yes         No       1
# 7023  1035-IPQPU  Female              1     Yes         No      63
# 7029  2235-DWLJU  Female              1      No         No       6
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 30            Yes               Yes     Fiber optic            Yes  ...
# ...

# %% [markdown]
# # Question 3

# %%
plt.scatter(zen["tenure"],zen["TotalCharges"],s=10,marker="*")
plt.xlabel("Tenure")
plt.ylabel("Total Charges")
plt.title("Relation between tenure vs Total charges")
# Out:
# Text(0.5, 1.0, 'Relation between tenure vs Total charges')

# %% [markdown]
# # Question 4

# %%
SC=zen.loc[(zen["SeniorCitizen"]==1)]
SC.head()
# Out:
#     customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 20  8779-QRDMV    Male              1      No         No       1           No
# 30  3841-NFECX  Female              1     Yes         No      71          Yes
# 31  4929-XIHVW    Male              1     Yes         No       2          Yes
# 34  3413-BMNZE    Male              1      No         No       1          Yes
# 50  8012-SOUDQ  Female              1      No         No      43          Yes
#
#        MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 20  No phone service             DSL             No  ...              Yes
# 30               Yes     Fiber optic            Yes  ...              Yes
# 31                No     Fiber optic             No  ...              Yes
# 34                No             DSL             No  ...               No
# 50               Yes     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# # Question 5

# %%
sns.countplot(zen["PaymentMethod"],hue=zen["gender"])
plt.xticks(rotation=45)
# Out:
# C:\Users\AYISHA M\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# (array([0, 1, 2, 3]),
#  [Text(0, 0, 'Electronic check'),
#   Text(1, 0, 'Mailed check'),
#   Text(2, 0, 'Bank transfer (automatic)'),
#   Text(3, 0, 'Credit card (automatic)')])
